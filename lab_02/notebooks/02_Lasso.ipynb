# %% [markdown]
# # LASSO
#
# Lasso es un método de regularización que favorece que algunos de los coeficientes terminen valiendo 0. Esto quiere decir que el modelo va a ignorar algunas de las características predictivas, lo que puede ser considerado un tipo de selección automática de características. El incluir menos características supone un modelo más sencillo de interpretar que puede poner de manifiesto las características más importantes del conjunto de datos. En el caso de que exista cierta correlación entre las características predictivas, Lasso tenderá a escoger una de ellas al azar
#
# __Importamos todas las librerías que se van a utilizar en este notebook:__

# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt # plots
import seaborn as sns # plots
from sklearn.ensemble import IsolationForest
from sklearn import preprocessing 
from sklearn.linear_model import Lasso, LassoCV
import pickle

# %% [markdown]
# Importamos los datos resultantes del notebook anterior, considerados como data_cleaned, ya que hemos realizado las labores de data engeneering necesarias.

# %%
path = ('../data/02_intermediate/data_cleaned.csv') # importamos los datos de la carpteta
data_cleaned = pd.read_csv(path)

# %%
data_cleaned.head() # visulalizamos la carga de los datos
# Out:
#    Unnamed: 0         id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0           8  112038251      11575        11575          11575.0
# 1          10  112149045       7200         7200           7200.0
# 2          24  112052261       7500         7500           7500.0
# 3          42  111999259      10000        10000          10000.0
# 4          91  111808508      14000        14000          14000.0
#
#    installment  annual_inc    dti  delinq_2yrs  fico_range_low  ...  \
# 0       359.26    153000.0  16.99            0             720  ...
# 1       285.70     50000.0   6.07            0             685  ...
# 2       232.79    110000.0  13.12            0             710  ...
# 3       243.29     51979.0  10.11            0             690  ...
# 4       492.34     75000.0  10.86            1             685  ...
#
#    verification_status_Source Verified  verification_status_Verified  \
# 0                                    0                             0
# 1                                    1                             0
# 2                                    0                             0
# 3                                    1                             0
# 4                                    0                             1
#
#    purpose_credit_card  purpose_debt_consolidation  purpose_housing  \
# 0                    1                           0                0
# 1                    0                           1                0
# 2                    0                           1                0
# 3                    0                           1                0
# 4                    0                           1                0
#
#    purpose_leisure  purpose_medical  purpose_other  \
# 0                0                0              0
# 1                0                0              0
# 2                0                0              0
# 3                0                0              0
# 4                0                0              0
#
#    application_type_Individual  application_type_Joint App
# 0                            1                           0
# 1                            1                           0
# 2                            1                           0
# 3                            1                           0
# 4                            1                           0
#
# [5 rows x 100 columns]

# %%
# en la visualización vemos que se ha añadido una columna así que la eliminamos:
del data_cleaned['Unnamed: 0']

# %% [markdown]
# Nombramos y seleccionamos las variables predictoras y la variable target:

# %%
predictiveVariables = data_cleaned.loc[:, data_cleaned.columns != 'target'] #serán todas menos la varoables target

target = data_cleaned['target'] # es la variable 'target' de la bbdd importada

# %% [markdown]
# ## Definimos el modelo LASSO:
# Como este modelo va a ser utilizado para seleccionar aquellas variables más relevantes definimos que realice 500 iteraciones y cross validation, además lo realizará con toda la muestra ya que en este caso no será utilizado para futurass predicciones o clasificaciones

# %%
# %%time
lassocv = LassoCV(alphas = None, # no predefinimos los alphas, queremos que los seleccione el propio modelo
                  cv = 10, # indicamos que el cross validation realice 10K
                  max_iter = 500, # número máximo de iteraciones = 500
                  normalize = True) # normalizamos las variables

# entrenamos el modelo de cross validation con toda la muestra:
lassocv.fit(predictiveVariables, target)

# valores de alpha seleccionados por el modelo:
lassocv.alpha_


# definimos: lasso function, en el que el alpha será el calculado anteriormente
model_lasso = Lasso(alpha=lassocv.alpha_) 
# entrenamos el modelo lasso con toda la muestra
model_lasso.fit(predictiveVariables, target)
# Out:
# Wall time: 2min 38s
# C:\Users\Beatriz\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18833.34019394814, tolerance: 8.72197076966072
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=4.453967939231418e-07)

# %% [markdown]
# Como se ha comentado anteriormente este modelo lo realizamos para conocer las variables más significativas del modelo. Por lo tanto, el objetivo es conocer los coeficientes resulates del modelo Lasso:

# %%
# coefficientes lasso de las variables predictoras:
lasso_coefficients = pd.DataFrame(model_lasso.coef_, set(predictiveVariables), columns = ['Coefficients'])

# término independiente del modelo Lasso
lasso_coefficients.loc['Intercept'] = model_lasso.intercept_
lasso_coefficients

# data frame de los coeficientes Lasso
df_lasso = pd.DataFrame(lasso_coefficients)

# ordenamos las variables en función de sus coeficientes
df_lasso_ordered = df_lasso.sort_values(by = "Coefficients")

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None) # para que muestre todos los valores del df

print(df_lasso_ordered)
# Out:
#                                      Coefficients
# num_bc_sats                         -1.194939e-01
# mort_acc                            -1.127738e-01
# id                                  -9.558519e-02
# home_ownership_ANY                  -1.738155e-02
# purpose_credit_card                 -1.451818e-02
# num_rev_tl_bal_gt_0                 -1.352649e-02
# loan_amnt                           -1.150573e-02
# last_fico_range_high                -8.425800e-03
# pct_tl_nvr_dlq                      -6.799665e-03
# tot_coll_amt                        -5.603795e-03
# mths_since_recent_inq               -5.126447e-03
# tax_liens                           -4.575474e-03
# num_sats                            -3.980897e-03
# fico_range_low                      -3.462910e-03
# delinq_amnt                         -3.419417e-03
# purpose_housing                     -3.237984e-03
# mths_since_last_major_derog         -2.501222e-03
# avg_cur_bal                         -2.316511e-03
# mo_sin_rcnt_rev_tl_op               -2.055137e-03
# num_tl_op_past_12m                  -1.993768e-03
# open_acc                            -1.832282e-03
# emp_length_> 10 years               -1.438539e-03
# mths_since_last_delinq              -1.402582e-03
# num_accts_ever_120_pd               -1.347100e-03
# all_util                            -1.160830e-03
# open_il_24m                         -1.022762e-03
# open_acc_6m                         -9.977818e-04
# chargeoff_within_12_mths            -8.553025e-04
# mo_sin_old_il_acct                  -7.333529e-04
# annual_inc                          -5.745771e-04
# num_op_rev_tl                       -5.738389e-04
# verification_status_Verified        -4.919590e-04
# bc_open_to_buy                      -4.386361e-04
# fico_range_high                     -2.102958e-04
# total_bal_il                        -1.211567e-04
# term_ 36 months                     -2.386500e-05
# total_bc_limit                      -2.252077e-05
# policy_code                         -1.700165e-05
# last_fico_range_low                 -5.135281e-06
# inq_fi                              -2.074168e-06
# pub_rec                             -8.597547e-07
# emp_length_< 5 years                -4.365141e-07
# funded_amnt_inv                     -3.884636e-07
# purpose_debt_consolidation          -2.967197e-07
# inq_last_6mths                      -7.404472e-08
# purpose_other                       -6.589077e-08
# acc_open_past_24mths                -3.906022e-08
# total_acc                           -1.236456e-08
# total_il_high_credit_limit          -3.681326e-22
# inq_last_12m                         0.000000e+00
# collections_12_mths_ex_med           0.000000e+00
# tot_hi_cred_lim                      0.000000e+00
# percent_bc_gt_75                     0.000000e+00
# collection_recovery_fee              1.878381e-09
# num_tl_120dpd_2m                     8.311852e-09
# bc_util                              9.220505e-08
# open_rv_12m                          1.318496e-07
# mths_since_recent_revol_delinq       1.794834e-07
# mths_since_recent_bc                 2.786969e-07
# application_type_Joint App           8.366494e-07
# verification_status_Source Verified  1.298468e-05
# total_cu_tl                          2.684778e-05
# home_ownership_RENT                  2.942944e-05
# dti                                  3.274621e-05
# total_bal_ex_mort                    4.678620e-05
# num_actv_rev_tl                      5.765404e-05
# pub_rec_bankruptcies                 8.916316e-05
# il_util                              1.201075e-04
# mths_since_last_record               1.226300e-04
# term_ 60 months                      1.320813e-04
# application_type_Individual          2.192764e-04
# mo_sin_rcnt_tl                       2.348417e-04
# purpose_medical                      2.957206e-04
# mths_since_recent_bc_dlq             4.658032e-04
# num_il_tl                            5.697594e-04
# open_rv_24m                          5.976542e-04
# revol_bal                            6.861877e-04
# delinq_2yrs                          7.192295e-04
# num_bc_tl                            7.968772e-04
# mo_sin_old_rev_tl_op                 8.780613e-04
# open_act_il                          1.067801e-03
# num_tl_30dpd                         1.089198e-03
# num_actv_bc_tl                       1.312290e-03
# installment                          1.522947e-03
# home_ownership_MORTGAGE              1.597383e-03
# emp_length_5-10 years                1.767733e-03
# max_bal_bc                           2.421622e-03
# funded_amnt                          2.666968e-03
# num_tl_90g_dpd_24m                   2.953470e-03
# tot_cur_bal                          3.029605e-03
# acc_now_delinq                       3.451292e-03
# open_il_12m                          3.883357e-03
# verification_status_Not Verified     4.124248e-03
# num_rev_accts                        5.175942e-03
# purpose_leisure                      5.454479e-03
# mths_since_rcnt_il                   1.481098e-02
# total_rev_hi_lim                     1.774193e-02
# home_ownership_OWN                   2.807087e-02
# Intercept                            1.686347e+00

# %% [markdown]
# Considerando el valor absoluto de los coeficientes, hemos determinado que seleccionaremos aquellas variables que su coeficientes sea > |0.001|.

# %%
# seleccionamos aquellas variables con coef >  |0.001|
important_variables = lasso_coefficients[(lasso_coefficients['Coefficients'] > 0.001) |
                                         (lasso_coefficients['Coefficients'] < -0.001)]

# visualizamos las variables  y los coeficientes que cumplen este requisito
lasso_coefficients_001 = important_variables.sort_values(['Coefficients'])
lasso_coefficients_001
# Out:
#                                   Coefficients
# num_bc_sats                          -0.119494
# mort_acc                             -0.112774
# id                                   -0.095585
# home_ownership_ANY                   -0.017382
# purpose_credit_card                  -0.014518
# num_rev_tl_bal_gt_0                  -0.013526
# loan_amnt                            -0.011506
# last_fico_range_high                 -0.008426
# pct_tl_nvr_dlq                       -0.006800
# tot_coll_amt                         -0.005604
# mths_since_recent_inq                -0.005126
# tax_liens                            -0.004575
# num_sats                             -0.003981
# fico_range_low                       -0.003463
# delinq_amnt                          -0.003419
# purpose_housing                      -0.003238
# mths_since_last_major_derog          -0.002501
# avg_cur_bal                          -0.002317
# mo_sin_rcnt_rev_tl_op                -0.002055
# num_tl_op_past_12m                   -0.001994
# open_acc                             -0.001832
# emp_length_> 10 years                -0.001439
# mths_since_last_delinq               -0.001403
# num_accts_ever_120_pd                -0.001347
# all_util                             -0.001161
# open_il_24m                          -0.001023
# open_act_il                           0.001068
# num_tl_30dpd                          0.001089
# num_actv_bc_tl                        0.001312
# installment                           0.001523
# home_ownership_MORTGAGE               0.001597
# emp_length_5-10 years                 0.001768
# max_bal_bc                            0.002422
# funded_amnt                           0.002667
# num_tl_90g_dpd_24m                    0.002953
# tot_cur_bal                           0.003030
# acc_now_delinq                        0.003451
# open_il_12m                           0.003883
# verification_status_Not Verified      0.004124
# num_rev_accts                         0.005176
# purpose_leisure                       0.005454
# mths_since_rcnt_il                    0.014811
# total_rev_hi_lim                      0.017742
# home_ownership_OWN                    0.028071
# Intercept                             1.686347

# %%
lasso_coefficients_001.shape
# Out:
# (45, 1)

# %% [markdown]
# Vemos que aplicanto este criterio son 45 variables las resultantes, éstas serán las que utilicemos en los próximos modelos:

# %%
final_variables = list(lasso_coefficients_001.index) # seleccionamos las variables que cumple el criterio coef >|0.001|
final_variables
# Out:
# ['num_bc_sats',
#  'mort_acc',
#  'id',
#  'home_ownership_ANY',
#  'purpose_credit_card',
#  'num_rev_tl_bal_gt_0',
#  'loan_amnt',
#  'last_fico_range_high',
#  'pct_tl_nvr_dlq',
#  'tot_coll_amt',
#  'mths_since_recent_inq',
#  'tax_liens',
#  'num_sats',
#  'fico_range_low',
#  'delinq_amnt',
#  'purpose_housing',
#  'mths_since_last_major_derog',
#  'avg_cur_bal',
#  'mo_sin_rcnt_rev_tl_op',
#  'num_tl_op_past_12m',
#  'open_acc',
#  'emp_length_> 10 years',
#  'mths_since_last_delinq',
#  'num_accts_ever_120_pd',
#  'all_util',
#  'open_il_24m',
#  'open_act_il',
#  'num_tl_30dpd',
#  'num_actv_bc_tl',
#  'installment',
#  'home_ownership_MORTGAGE',
#  'emp_length_5-10 years',
#  'max_bal_bc',
#  'funded_amnt',
#  'num_tl_90g_dpd_24m',
#  'tot_cur_bal',
#  'acc_now_delinq',
#  'open_il_12m',
#  'verification_status_Not Verified',
#  'num_rev_accts',
#  'purpose_leisure',
#  'mths_since_rcnt_il',
#  'total_rev_hi_lim',
#  'home_ownership_OWN',
#  'Intercept']

# %% [markdown]
# Guardamos en un data frame los datos de las variables seleccionadas:

# %%
final_df = data_cleaned.loc[:, ['num_tl_30dpd',
                                 'tot_hi_cred_lim',
                                 'revol_bal',
                                 'purpose_debt_consolidation',
                                 'home_ownership_ANY',
                                 'max_bal_bc',
                                 'total_cu_tl',
                                 'open_rv_24m',
                                 'num_tl_120dpd_2m',
                                 'open_il_12m',
                                 'mo_sin_rcnt_rev_tl_op',
                                 'num_il_tl',
                                 'id',
                                 'dti',
                                 'num_tl_90g_dpd_24m',
                                 'funded_amnt',
                                 'purpose_credit_card',
                                 'open_acc_6m',
                                 'inq_last_6mths',
                                 'application_type_Joint App',
                                 'mort_acc',
                                 'policy_code',
                                 'percent_bc_gt_75',
                                 'mths_since_recent_bc_dlq',
                                 'term_ 60 months',
                                 'mths_since_recent_bc',
                                 'num_accts_ever_120_pd',
                                 'last_fico_range_low',
                                 'purpose_medical',
                                 'installment',
                                 'collections_12_mths_ex_med',
                                 'open_il_24m',
                                 'fico_range_high',
                                 'verification_status_Verified',
                                 'purpose_housing',
                                 'mths_since_recent_revol_delinq',
                                 'total_bal_ex_mort',
                                 'num_sats',
                                 'home_ownership_MORTGAGE',
                                 'mths_since_last_record',
                                 'pub_rec',
                                 'delinq_amnt',
                                 'num_bc_tl',
                                 'mths_since_rcnt_il']]
final_df.head()
# Out:
#    num_tl_30dpd  tot_hi_cred_lim  revol_bal  purpose_debt_consolidation  \
# 0             0           528172       8550                           0
# 1             0             7600       3560                           1
# 2             0           350617      23348                           1
# 3             0            34200       5733                           1
# 4             0           170591       2700                           1
#
#    home_ownership_ANY  max_bal_bc  total_cu_tl  open_rv_24m  num_tl_120dpd_2m  \
# 0                   0      1581.0          6.0          8.0               0.0
# 1                   0      2779.0          0.0          1.0               0.0
# 2                   0      5965.0          8.0          6.0               0.0
# 3                   0      3898.0          0.0          5.0               0.0
# 4                   0      2700.0          0.0          3.0               0.0
#
#    open_il_12m  mo_sin_rcnt_rev_tl_op  num_il_tl         id    dti  \
# 0          0.0                      3         12  112038251  16.99
# 1          0.0                     14          1  112149045   6.07
# 2          1.0                      3          8  112052261  13.12
# 3          1.0                      6          4  111999259  10.11
# 4          1.0                      5          3  111808508  10.86
#
#    num_tl_90g_dpd_24m  funded_amnt  purpose_credit_card  open_acc_6m  \
# 0                   0        11575                    1          1.0
# 1                   0         7200                    0          0.0
# 2                   0         7500                    0          1.0
# 3                   0        10000                    0          1.0
# 4                   0        14000                    0          1.0
#
#    inq_last_6mths  application_type_Joint App  mort_acc  policy_code  \
# 0               0                           0         2            1
# 1               0                           0         0            1
# 2               2                           0         4            1
# 3               0                           0         0            1
# 4               0                           0         1            1
#
#    percent_bc_gt_75  mths_since_recent_bc_dlq  term_ 60 months  \
# 0              11.1                     176.0                0
# 1             100.0                     176.0                0
# 2               8.3                     176.0                0
# 3               0.0                     176.0                1
# 4             100.0                     176.0                0
#
#    mths_since_recent_bc  num_accts_ever_120_pd  last_fico_range_low  \
# 0                   3.0                      0                  720
# 1                  14.0                      1                  665
# 2                   3.0                      0                  715
# 3                   6.0                      0                  655
# 4                   8.0                      0                  680
#
#    purpose_medical  installment  collections_12_mths_ex_med  open_il_24m  \
# 0                0       359.26                           0          0.0
# 1                0       285.70                           0          1.0
# 2                0       232.79                           0          5.0
# 3                0       243.29                           0          2.0
# 4                0       492.34                           0          2.0
#
#    fico_range_high  verification_status_Verified  purpose_housing  \
# 0              724                             0                0
# 1              689                             0                0
# 2              714                             0                0
# 3              694                             0                0
# 4              689                             1                0
#
#    mths_since_recent_revol_delinq  total_bal_ex_mort  num_sats  \
# 0                           180.0             100865        20
# 1                           180.0               5588         4
# 2                           180.0              45955        19
# 3                           180.0              10956        15
# 4                           180.0              27684         4
#
#    home_ownership_MORTGAGE  mths_since_last_record  pub_rec  delinq_amnt  \
# 0                        0                    84.0        1            0
# 1                        0                   121.0        0            0
# 2                        1                   121.0        0            0
# 3                        0                    55.0        2            0
# 4                        1                   121.0        0            0
#
#    num_bc_tl  mths_since_rcnt_il
# 0         16                27.0
# 1          3                21.0
# 2         13                 7.0
# 3          8                 9.0
# 4          5                 7.0

# %% [markdown]
# Añadimos la variable 'target' al df final que usaremos en nuestros modelos

# %%
final_df['target'] = data_cleaned['target'] # renombramos el df ya que va ser el final para nuestros modelos
final_df.head()
# Out:
#    num_tl_30dpd  tot_hi_cred_lim  revol_bal  purpose_debt_consolidation  \
# 0             0           528172       8550                           0
# 1             0             7600       3560                           1
# 2             0           350617      23348                           1
# 3             0            34200       5733                           1
# 4             0           170591       2700                           1
#
#    home_ownership_ANY  max_bal_bc  total_cu_tl  open_rv_24m  num_tl_120dpd_2m  \
# 0                   0      1581.0          6.0          8.0               0.0
# 1                   0      2779.0          0.0          1.0               0.0
# 2                   0      5965.0          8.0          6.0               0.0
# 3                   0      3898.0          0.0          5.0               0.0
# 4                   0      2700.0          0.0          3.0               0.0
#
#    open_il_12m  mo_sin_rcnt_rev_tl_op  num_il_tl         id    dti  \
# 0          0.0                      3         12  112038251  16.99
# 1          0.0                     14          1  112149045   6.07
# 2          1.0                      3          8  112052261  13.12
# 3          1.0                      6          4  111999259  10.11
# 4          1.0                      5          3  111808508  10.86
#
#    num_tl_90g_dpd_24m  funded_amnt  purpose_credit_card  open_acc_6m  \
# 0                   0        11575                    1          1.0
# 1                   0         7200                    0          0.0
# 2                   0         7500                    0          1.0
# 3                   0        10000                    0          1.0
# 4                   0        14000                    0          1.0
#
#    inq_last_6mths  application_type_Joint App  mort_acc  policy_code  \
# 0               0                           0         2            1
# 1               0                           0         0            1
# 2               2                           0         4            1
# 3               0                           0         0            1
# 4               0                           0         1            1
#
#    percent_bc_gt_75  mths_since_recent_bc_dlq  term_ 60 months  \
# 0              11.1                     176.0                0
# 1             100.0                     176.0                0
# 2               8.3                     176.0                0
# 3               0.0                     176.0                1
# 4             100.0                     176.0                0
#
#    mths_since_recent_bc  num_accts_ever_120_pd  last_fico_range_low  \
# 0                   3.0                      0                  720
# 1                  14.0                      1                  665
# 2                   3.0                      0                  715
# 3                   6.0                      0                  655
# 4                   8.0                      0                  680
#
#    purpose_medical  installment  collections_12_mths_ex_med  open_il_24m  \
# 0                0       359.26                           0          0.0
# 1                0       285.70                           0          1.0
# 2                0       232.79                           0          5.0
# 3                0       243.29                           0          2.0
# 4                0       492.34                           0          2.0
#
#    fico_range_high  verification_status_Verified  purpose_housing  \
# 0              724                             0                0
# 1              689                             0                0
# 2              714                             0                0
# 3              694                             0                0
# 4              689                             1                0
#
#    mths_since_recent_revol_delinq  total_bal_ex_mort  num_sats  \
# 0                           180.0             100865        20
# 1                           180.0               5588         4
# 2                           180.0              45955        19
# 3                           180.0              10956        15
# 4                           180.0              27684         4
#
#    home_ownership_MORTGAGE  mths_since_last_record  pub_rec  delinq_amnt  \
# 0                        0                    84.0        1            0
# 1                        0                   121.0        0            0
# 2                        1                   121.0        0            0
# 3                        0                    55.0        2            0
# 4                        1                   121.0        0            0
#
#    num_bc_tl  mths_since_rcnt_il  target
# 0         16                27.0       0
# 1          3                21.0       0
# 2         13                 7.0       0
# 3          8                 9.0       0
# 4          5                 7.0       0

# %% [markdown]
# #### Guardamos el modelo y los datos seleccionados:
#  - Guardamos el modelo

# %%
def save_models(filename, model): # definimos una funcion para guardar los modelos 
    with open(filename, 'wb') as file:
        pickle.dump(model, file) # IMPORTANTE ARCHIVO PICKLE

# %%
save_models('data/03_processed/model_lasso.pkl', model_lasso)

# %% [markdown]
#  - Guardamos los datos seleccionados en un CSV para poder utilizarlo en los siguientes modelos

# %%
ruta = '../data/03_processed/final_df.csv' # ruta para guardar el csv

# %%
final_df.to_csv(ruta)

# %% [markdown]
# Por último hemos creado un reporte a modo resumen EDA de los datos que serán utilizados en los modelos

# %%
# importing sweetviz
import sweetviz as sv
#analyzing the dataset
final_report = sv.analyze(final_df)
#display the report
final_report.show_html('../data/reporting_06/final_report.html')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, layout=Layout(flex='2'), max=46.0), HTML(value='')), l…
# Report final_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
